# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/BB_Evolution/blob/main/0042_AluraBB_DeepLearning_Keras_Parte01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning com Keras

# %%
! pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 462 kB 5.3 MB/s
# ...

# %%
# importaçoes
import tensorflow
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
# importando o dataset
dataset = keras.datasets.fashion_mnist
((imagens_treino, identificacoes_treino),(imagens_teste, identificacoes_teste)) = dataset.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# explorando o dataset
print('Shape imagens_treino', imagens_treino.shape)
print('Shape identificacoes_treino', identificacoes_treino.shape)
print()
print('Shape imagens_teste', imagens_teste.shape)
print('Shape identificacoes_teste', identificacoes_teste.shape)
print()
print('classe inicial', identificacoes_treino.min())
print('classe final', identificacoes_treino.max())
total_de_classificacoes = 10
print()
# Out:
# Shape imagens_treino (60000, 28, 28)
# Shape identificacoes_treino (60000,)
#
# Shape imagens_teste (10000, 28, 28)
# Shape identificacoes_teste (10000,)
#
# classe inicial 0
# classe final 9

# %% [markdown]
# **Classes (labels) do Keras Fashion-MNIST**
#
# https://keras.io/api/datasets/fashion_mnist/
#
# Label -> Description <br/>
# 0 -> T-shirt/top  <br/>
# 1 -> Trouser <br/>
# 2 -> Pullover <br/>
# 3 -> Dress <br/>
# 4 -> Coat <br/>
# 5 -> Sandal <br/>
# 6 -> Shirt <br/>
# 7 -> Sneaker <br/>
# 8 -> Bag <br/>
# 9 -> Ankle boot <br/>

# %%
# exibir os dados
nomes_de_classificacoes = ['Camiseta', 'Calça', 'Pullover', 'Vestido', 'Casaco', 
                           'Sandália', 'Camisa', 'Tênis', 'Bolsa', 'Bota']
for imagem in range(10):
    plt.subplot(2, 5, imagem+1)
    plt.imshow(imagens_treino[imagem])
    plt.title(nomes_de_classificacoes[identificacoes_treino[imagem]])

# %%
plt.imshow(imagens_treino[0])
plt.colorbar()

# %% [markdown]
# Modelo - sequencia: <br/>
# - entrada;
# - processamento;
# - saída.

# %%
# Criando o modelo

imagens_treino = imagens_treino/255.0 # normalização

modelo = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)), # entrada (pôr a dimensão das minhas matrizes [imagens]) - CAMADA 0
    keras.layers.Dense(256, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 1
    keras.layers.Dense(10, activation = tensorflow.nn.softmax) # saida (pôr a quantidade de classes) - CAMADA 2
])

modelo.compile(optimizer = 'adam', 
               loss = 'sparse_categorical_crossentropy') # Loss = entropia categórica cruzada esparsa

modelo.fit(imagens_treino, identificacoes_treino)
# Out:
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4852

# %%
# veja imagem normalizada: (0-1):

plt.imshow(imagens_treino[0])
plt.colorbar()

# %% [markdown]
# E aí queria trazer para vocês uma discussão que existe em relação ao que é considerado multicamadas ou profundas. Neste caso, por ele ter 2 camadas, algumas pessoas consideram que já é Deep Learning, um Aprendizado Profundo, e outras diriam que ainda precisamos de mais camadas intermediárias para isso.
#
# Se copiássemos a linha com relu, por exemplo, e colássemos mais vezes na célula, de acordo com essas pessoas, agora sim, teríamos um Aprendizado Profundo. Definições à parte, o primeiro modelo que analisaremos é este com várias camadas, ou multilayers. Só queria trazer isso para vocês entenderem que temos 2 camadas, porque a primeira é a 0.

# %%
dataset = keras.datasets.fashion_mnist
((imagens_treino, identificacoes_treino),(imagens_teste, identificacoes_teste)) = dataset.load_data()

# exibir os dados
nomes_de_classificacoes = ['Camiseta', 'Calça', 'Pullover', 'Vestido', 'Casaco', 
                           'Sandália', 'Camisa', 'Tênis', 'Bolsa', 'Bota']
for imagem in range(10):
    plt.subplot(2, 5, imagem+1)
    plt.imshow(imagens_treino[imagem])
    plt.title(nomes_de_classificacoes[identificacoes_treino[imagem]])
    plt.colorbar()

# %%
# Criando o modelo

imagens_treino = imagens_treino/255.0 # normalização

modelo = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)), # entrada (pôr a dimensão das minhas matrizes [imagens]) - CAMADA 0
    keras.layers.Dense(256, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 1
    keras.layers.Dense(128, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 2
    keras.layers.Dense(64, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 3    
    keras.layers.Dense(10, activation = tensorflow.nn.softmax) # saida (pôr a quantidade de classes) - CAMADA 4
])

modelo.compile(optimizer = 'adam', 
               loss = 'sparse_categorical_crossentropy') # Loss = entropia categórica cruzada esparsa

modelo.fit(imagens_treino, identificacoes_treino)
# Out:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4897

# %% [markdown]
# Ver:
#
# http://scipy-lectures.org/advanced/image_processing/

# %%
dataset = keras.datasets.fashion_mnist
((imagens_treino, identificacoes_treino),(imagens_teste, identificacoes_teste)) = dataset.load_data()

# exibir os dados
nomes_de_classificacoes = ['Camiseta', 'Calça', 'Pullover', 'Vestido', 'Casaco', 
                           'Sandália', 'Camisa', 'Tênis', 'Bolsa', 'Bota']
for imagem in range(10):
    plt.subplot(2, 5, imagem+1)
    plt.imshow(imagens_treino[imagem])
    plt.title(nomes_de_classificacoes[identificacoes_treino[imagem]])
    plt.colorbar()

# %%
dataset = keras.datasets.fashion_mnist
((imagens_treino, identificacoes_treino),(imagens_teste, identificacoes_teste)) = dataset.load_data()

# Criando o modelo

imagens_treino = imagens_treino/255.0 # normalização

epochs = 30

modelo = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)), # entrada (pôr a dimensão das minhas matrizes [imagens]) - CAMADA 0
    keras.layers.Dense(256, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 1
    keras.layers.Dropout(0.2), # isso deixa 20% das camadas acima adormecidas, pode favorecer o ajuste do modelo 
    keras.layers.Dense(128, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 2
    keras.layers.Dropout(0.2), # isso deixa 20% das camadas acima adormecidas, pode favorecer o ajuste do modelo 
    keras.layers.Dense(64, activation = tensorflow.nn.relu), # processamento (pôr a dimensão em multiplos de 2 e uma função de ativação) - CAMADA 3     
    keras.layers.Dropout(0.2), # isso deixa 20% das camadas acima adormecidas, pode favorecer o ajuste do modelo       
    keras.layers.Dense(10, activation = tensorflow.nn.softmax) # saida (pôr a quantidade de classes) - CAMADA 4
])

modelo.compile(optimizer = 'adam', 
               loss = 'sparse_categorical_crossentropy',
               metrics=['accuracy']) # Loss = entropia categórica cruzada esparsa

historico = modelo.fit(imagens_treino, identificacoes_treino, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.6214 - accuracy: 0.7790 - val_loss: 0.4251 - val_accuracy: 0.8473
# Epoch 2/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4465 - accuracy: 0.8402 - val_loss: 0.4092 - val_accuracy: 0.8523
# Epoch 3/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4077 - accuracy: 0.8542 - val_loss: 0.3702 - val_accuracy: 0.8662
# Epoch 4/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3860 - accuracy: 0.8611 - val_loss: 0.3708 - val_accuracy: 0.8699
# Epoch 5/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3657 - accuracy: 0.8687 - val_loss: 0.3570 - val_accuracy: 0.8698
# Epoch 6/30
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3509 - accuracy: 0.8721 - val_loss: 0.3491 - val_accuracy: 0.8783
# Epoch 7/30
# ...

# %%
historico.history
# Out:
# {'accuracy': [0.7790208458900452,
#   0.8402083516120911,
#   0.8542083501815796,
#   0.8611249923706055,
#   0.8687083125114441,
#   0.8720625042915344,
#   0.8769583106040955,
#   0.879645824432373,
#   0.882729172706604,
#   0.885729193687439,
#   0.8882708549499512,
#   0.8891458511352539,
#   0.8914166688919067,
#   0.8939375281333923,
#   0.8939791917800903,
#   0.8961041569709778,
#   0.8967291712760925,
#   0.9002291560173035,
#   0.9020000100135803,
#   0.903124988079071,
#   0.9053958058357239,
#   0.906374990940094,
#   0.9059791564941406,
#   0.9067500233650208,
#   0.9086666703224182,
#   0.9096249938011169,
#   0.909208357334137,
#   0.9106249809265137,
#   0.9107083082199097,
#   0.9142083525657654],
#  'loss': [0.6213896870613098,
#   0.44652020931243896,
#   0.40771350264549255,
#   0.3859884440898895,
#   0.3657463788986206,
#   0.3508579432964325,
#   0.33901384472846985,
#   0.32915639877319336,
#   0.32049256563186646,
#   0.3127291798591614,
# ...

# %%
plt.plot(historico.history['accuracy'], label='treino')
plt.plot(historico.history['val_accuracy'], label='validação')
plt.title('Acurácia por épocas')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.legend()
plt.show()

# %%
plt.plot(historico.history['loss'], label='treino')
plt.plot(historico.history['val_loss'], label='validação')
plt.title('Perda por épocas')
plt.xlabel('Épocas')
plt.ylabel('Perda')
plt.legend()
plt.show()

# %%
# salvando o modelo
from tensorflow.keras.models import load_model

modelo.save('modelo.h5')
modelo_salvo = load_model('modelo.h5')

# %%
# testes com o modelo salvo
perda, acuracia = modelo_salvo.evaluate(imagens_teste, identificacoes_teste)
print('perda do teste (modelo salvo):', perda)
print('acurácia do teste (modelo salvo):', acuracia)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 43.1932 - accuracy: 0.8778
# perda do teste (modelo salvo): 43.193153381347656
# acurácia do teste (modelo salvo): 0.8777999877929688

# %%
testes = modelo.predict(imagens_teste)
print('resultado teste:', np.argmax(testes[0])) # o argmax retorna de one-hot enconding para o número da classe
print('classe da imagem de teste:', identificacoes_teste[0])
# Out:
# resultado teste: 9
# classe da imagem de teste: 9

# %%
teste = [0, 4, 10, 2, 4, 5, 6, 7]
np.argmax(teste) # retorna qual o índice com o maior valor
# Out:
# 2

# %%
# num on-hot encode, o argmax retorna o local onde está o 1
# exemplo:

onehot1 = [0, 0, 0, 1]
onehot2 = [0, 0, 1, 0]
onehot3 = [0, 1, 0, 0]
onehot4 = [1, 0, 0, 0]

print('onehot1', np.argmax(onehot1))
print('onehot2', np.argmax(onehot2))
print('onehot3', np.argmax(onehot3))
print('onehot4', np.argmax(onehot4))
# Out:
# onehot1 3
# onehot2 2
# onehot3 1
# onehot4 0
